# %% [markdown]
# <a href="https://colab.research.google.com/github/gadichandu3-prog/inership_datadrame-_import/blob/main/intership_class2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
for i in range (0,5,1):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
for i in range(5):#pass
    if i==3:
        pass
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
for i in range(5):#continue
    if i==3:
        continue
    print(i)
# Out:
# 0
# 1
# 2
# 4

# %%
for i in range(5):#break
    if i==3:
        break
    print(i)
# Out:
# 0
# 1
# 2

# %%
l=[]
print(l)
# Out:
# []

# %%
l=[1,2,3,5,4]
print(l)
# Out:
# [1, 2, 3, 5, 4]

# %%
l.append(6)
print(l)
# Out:
# [1, 2, 3, 5, 4, 6]

# %%
l.pop()
print(l)
# Out:
# [1, 2, 3, 5, 4]

# %%
l.sort()
print(l)
# Out:
# [1, 2, 3, 4, 5]

# %%
print(l)
# Out:
# [1, 2, 3, 4, 5]

# %%
l.count(5)
# Out:
# 1
