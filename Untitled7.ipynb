# %% [markdown]
# <a href="https://colab.research.google.com/github/gadichandu3-prog/inership_datadrame-_import/blob/main/Untitled7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
f= open('abc.txt','w')
print("File name:",f.name)# file handling properties
print("File Mode:",f.mode)
print(f.readable())
print(f.writable())
print(f.closed)
f.close()
print(f.closed)
# Out:
# File name: abc.txt
# File Mode: w
# False
# True
# False
# True

# %%
with open("abc.txt", "r") as file:#used to close the file automatically after use
    content= file.read()# read the complete data
print(content)

# %%
with open("abc.txt", "r") as file:#used to close the file automatically after use
    content= file.readline()#read the first line of data
print(content)

# %%
with open("abc.txt", "w") as file:#used to close the file automatically after use
    content= file.write("nihaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa")# write the string data in the file

# %%
l=["chandu\n","Kishore\n","mural\n"]# write the list data in a file
with open("abc.txt", "w") as file:#used to close the file automatically after use
    content= file.writelines(l)

# %%
with open("abc.txt", "a") as file:#used to close the file automatically after use
    content= file.write("nalllllllllllllllllllllllll")# add the data without removing the previou

# %%
import csv # import csv module
with open("niha.csv", "w",newline="") as file:
    s= csv.writer(file)
    s.writerow(["kishore","Age","City"])
    s.writerow(["muural",45,"kkd"])

# %%
import csv # import csv module
with open("niha.csv", "r") as file:# using reader function rows
    s= csv.reader(file)
    for row in s:
        print(row)
# Out:
# ['kishore', 'Age', 'City']
# ['muural', '45', 'kkd']
