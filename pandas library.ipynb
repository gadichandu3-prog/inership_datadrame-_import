# %% [markdown]
# <a href="https://colab.research.google.com/github/gadichandu3-prog/inership_datadrame-_import/blob/main/pandas%20library.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
pd.__version__
# Out:
# '2.2.2'

# %%
s=pd.Series([1,2,3,]) # one column
print(s)
# Out:
# 0    1
# 1    2
# 2    3
# dtype: int64

# %%
df=pd.DataFrame({
    "name": ["kishore","Surya"],
    "age":[12,34]})
df
# Out:
#       name  age
# 0  kishore   12
# 1    Surya   34

# %%
import pandas as pd

# 1. Data ni Dictionary format lo rayali
data = {
    'Name': ['chandu', 'Suresh', 'kishore', 'shiva', 'mural', 'swamy', 'karthik', 'deeven', 'satish'],
    'Age': [45, 24, 34, 35, 23, 25, 24, 25, 25],
    'City': ['kkd', 'kkd', 'vzg', 'kkd', 'kkd', 'kkd', 'anakapalli', 'kkd', 'kkd']
}

# 2. Ee data ni DataFrame ga marchali
df = pd.DataFrame(data)

# 3. Output chudataniki
df
# Out:
#       Name  Age        City
# 0   chandu   45         kkd
# 1   Suresh   24         kkd
# 2  kishore   34         vzg
# 3    shiva   35         kkd
# 4    mural   23         kkd
# 5    swamy   25         kkd
# 6  karthik   24  anakapalli
# 7   deeven   25         kkd
# 8   satish   25         kkd

# %% [markdown]
# **writing the data into files**

# %%
df.to_csv('data.csv',index=False)

# %% [markdown]
# **Exploring data**

# %%
df.head()
# Out:
#       Name  Age City
# 0   chandu   45  kkd
# 1   Suresh   24  kkd
# 2  kishore   34  vzg
# 3    shiva   35  kkd
# 4    mural   23  kkd

# %%
df.tail()
# Out:
#       Name  Age        City
# 4    mural   23         kkd
# 5    swamy   25         kkd
# 6  karthik   24  anakapalli
# 7   deeven   25         kkd
# 8   satish   25         kkd

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    9 non-null      object
#  1   Age     9 non-null      int64
#  2   City    9 non-null      object
# dtypes: int64(1), object(2)
# memory usage: 348.0+ bytes

# %%
df['Name'][df['Age']=='Karthik']
# Out:
# Series([], Name: Name, dtype: object)

# %%
df.shape
# Out:
# (9, 3)

# %%
df[2:5]
# Out:
#       Name  Age City
# 2  kishore   34  vzg
# 3    shiva   35  kkd
# 4    mural   23  kkd

# %%
df.columns
# Out:
# Index(['Name', 'Age', 'City'], dtype='object')

# %%
df.Name
# Out:
# 0     chandu
# 1     Suresh
# 2    kishore
# 3      shiva
# 4      mural
# 5      swamy
# 6    karthik
# 7     deeven
# 8     satish
# Name: Name, dtype: object

# %%
df[['Name','Age']]
# Out:
#       Name  Age
# 0   chandu   45
# 1   Suresh   24
# 2  kishore   34
# 3    shiva   35
# 4    mural   23
# 5    swamy   25
# 6  karthik   24
# 7   deeven   25
# 8   satish   25

# %%
df.City
# Out:
# 0           kkd
# 1           kkd
# 2           vzg
# 3           kkd
# 4           kkd
# 5           kkd
# 6    anakapalli
# 7           kkd
# 8           kkd
# Name: City, dtype: object

# %%
df['Name'].max()
# Out:
# 'swamy'

# %%
df['Name'].min()
# Out:
# 'Suresh'

# %%
df['Age'].mean()
# Out:
# np.float64(28.88888888888889)

# %%
df['Age'].mode()
# Out:
# 0    25
# Name: Age, dtype: int64

# %%
df['Name'].describe()
# Out:
# count          9
# unique         9
# top       chandu
# freq           1
# Name: Name, dtype: object

# %%
df[df.Name==df.Name.max()]
# Out:
#     Name  Age City
# 5  swamy   25  kkd

# %%
df.Age[df.Name==df.Name.max()]
# Out:
# 5    25
# Name: Age, dtype: int64
